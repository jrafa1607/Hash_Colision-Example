# %%
#Exemplo de Colisão de Hashes
#Import das Bibliotecas

import os
import cv2
import hashlib
import matplotlib as mpl
from matplotlib import pyplot as plot

# %%
img1 = cv2.imread('D:/OneDrive/OneDrive - Etec Centro Paula Souza/Github/Criptografia/lenna.jpg')

# %%
#Visualizando a Imagem 01
plot.imshow(img1,cmap='gray')
plot.show()

# %%
img2 = cv2.imread('D:/OneDrive/OneDrive - Etec Centro Paula Souza/Github/Criptografia/lenna2.jpg')

# %%
#Visualizando a Imagem 02
plot.imshow(img2,cmap='gray')
plot.show()

# %%
print(hashlib.md5(img1).hexdigest())
# Out:
# 1c41558e371e3a4e42c5a2f797989a6c

# %%
file1 = 'D:/OneDrive/OneDrive - Etec Centro Paula Souza/Github/Criptografia/lenna.jpg'

# %%
with open(file1, 'rb') as f1:
    data1 = f1.read()

# %%
print("O valor Hash da imagem 01 é:", hashlib.md5(data1).hexdigest())
# Out:
# O valor Hash da imagem 01 é: 0eaf36d4881c513ca70b6684bfaa5b08

# %%
#Teste com Hash Perceptual

# %%
from PIL import Image
import imagehash

# %%
hashperc1 = imagehash.average_hash(Image.open('lenna.jpg'))
hashperc2 = imagehash.average_hash(Image.open('lenna2.jpg'))

print(hashperc1)
print(hashperc2)
# Out:
# b69cbd890b0b8f8c
# b69cbd890b0b8f8c

# %%
hashperc1 = imagehash.phash(Image.open('lenna.jpg'))
hashperc2 = imagehash.phash(Image.open('lenna2.jpg'))

print(hashperc1)
print(hashperc2)
# Out:
# 99c6562d7533a296
# 99c6562d7533a296

# %%
b69cbd890b0b8f8c

AScii

9 = 101
9 = 101
c = 58
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 b69cbd890b0b8f8c
#
# NameError: name 'b69cbd890b0b8f8c' is not defined
